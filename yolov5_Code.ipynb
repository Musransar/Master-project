# %% [markdown]
# ## Connecting with drive and some operating system steps for path

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# %%
path='/content/drive/MyDrive/tbx11k-simplified'
print(os.listdir(path))
# Out:
# ['data.csv', 'Dataset', 'images', 'data.gsheet', 'tb_classify.h5', 'yolov5_Code.ipynb', 'TB_256', 'bounding_box.ipynb', 'Yolo_data', 'train_test.ipynb', 'Results', 'VIT.ipynb']

# %%
os.chdir('/content/drive/MyDrive/tbx11k-simplified')

# %% [markdown]
# ## Cloning yolov5 Model

# %%
# #clone YOLOv5 and 
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15641, done.
# remote: Counting objects: 100% (248/248), done.
# remote: Compressing objects: 100% (149/149), done.
# remote: Total 15641 (delta 125), reused 173 (delta 99), pack-reused 15393
# Receiving objects: 100% (15641/15641), 14.65 MiB | 13.33 MiB/s, done.
# Resolving deltas: 100% (10649/10649), done.

# %%
# %cd yolov5
# %pip install -qr requirements.txt # install dependencies
# %pip install -q roboflow
# Out:
# /content/drive/MyDrive/tbx11k-simplified/yolov5
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 5.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 kB 2.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 8.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 6.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for wget (setup.py) ... done

# %%
import os
os.chdir('/content/drive/MyDrive/tbx11k-simplified/yolov5')

# %%
# !ls
# Out:
# benchmarks.py	 data	     LICENSE	      requirements.txt	tutorial.ipynb
# CITATION.cff	 detect.py   models	      segment		utils
# classify	 export.py   README.md	      setup.cfg		val.py
# CONTRIBUTING.md  hubconf.py  README.zh-CN.md  train.py

# %% [markdown]
# ## Training the Model

# %%
# !python train.py --img 256 --batch 16 --epochs 150 --data data/custom_model.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=data/custom_model.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=150, batch_size=16, imgsz=256, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# requirements: /content/drive/MyDrive/tbx11k-simplified/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-162-gc3e4e94 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLOv5 🚀 in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 17.9MB/s]
# Downloading https://github.com/ultralytics/yolov5/releases/download/v7.0/yolov5s.pt to yolov5s.pt...
# 100% 14.1M/14.1M [00:00<00:00, 93.8MB/s]
#
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# Model summary: 214 layers, 7022326 parameters, 7022326 gradients, 15.9 GFLOPs
#
# Transferred 343/349 items from yolov5s.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/drive/MyDrive/tbx11k-simplified/Yolo_data/TB_256/train... 639 images, 0 backgrounds, 0 corrupt: 100% 639/639 [00:16<00:00, 39.84it/s]
# train: New cache created: /content/drive/MyDrive/tbx11k-simplified/Yolo_data/TB_256/train.cache
# train: Caching images (0.1GB ram): 100% 639/639 [00:02<00:00, 294.69it/s]
# val: Scanning /content/drive/MyDrive/tbx11k-simplified/Yolo_data/TB_256/test... 160 images, 0 backgrounds, 0 corrupt: 100% 160/160 [00:02<00:00, 60.35it/s]
# val: New cache created: /content/drive/MyDrive/tbx11k-simplified/Yolo_data/TB_256/test.cache
# val: Caching images (0.0GB ram): 100% 160/160 [00:00<00:00, 295.26it/s]
#
# AutoAnchor: 6.15 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to runs/train/exp/labels.jpg...
# Image sizes 256 train, 256 val
# Using 2 dataloader workers
# Logging results to runs/train/exp
# Starting training for 150 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       0/149     0.793G     0.1068    0.01388          0         22        256: 100% 40/40 [00:07<00:00,  5.09it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:02<00:00,  2.02it/s]
#                    all        160        160    0.00435     0.0375    0.00318   0.000743
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       1/149     0.793G    0.08556    0.01691          0         30        256: 100% 40/40 [00:04<00:00,  8.24it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.48it/s]
#                    all        160        160     0.0139      0.537     0.0198    0.00391
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       2/149     0.797G    0.08111    0.01585          0         23        256: 100% 40/40 [00:03<00:00, 11.23it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.48it/s]
#                    all        160        160      0.189        0.1     0.0883     0.0229
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       3/149     0.797G    0.07337    0.01615          0         25        256: 100% 40/40 [00:05<00:00,  7.78it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.18it/s]
#                    all        160        160      0.134        0.3      0.128     0.0366
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       4/149     0.797G    0.06864    0.01604          0         28        256: 100% 40/40 [00:03<00:00, 11.18it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.68it/s]
#                    all        160        160       0.29      0.269      0.177     0.0458
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       5/149     0.797G    0.06396    0.01565          0         30        256: 100% 40/40 [00:03<00:00, 11.61it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.27it/s]
#                    all        160        160      0.217      0.475      0.202     0.0622
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       6/149     0.797G    0.06259    0.01472          0         29        256: 100% 40/40 [00:04<00:00,  8.63it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.51it/s]
#                    all        160        160      0.288      0.588      0.321        0.1
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       7/149     0.797G    0.05863    0.01447          0         26        256: 100% 40/40 [00:03<00:00, 11.42it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  6.03it/s]
#                    all        160        160      0.229       0.35      0.148     0.0409
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       8/149     0.797G    0.05952    0.01459          0         27        256: 100% 40/40 [00:05<00:00,  7.11it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  3.83it/s]
#                    all        160        160      0.237      0.362      0.186     0.0501
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       9/149     0.797G    0.05663    0.01412          0         21        256: 100% 40/40 [00:03<00:00, 11.41it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.84it/s]
#                    all        160        160      0.225      0.431      0.178     0.0541
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      10/149     0.797G    0.05727    0.01413          0         26        256: 100% 40/40 [00:03<00:00, 11.56it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.15it/s]
#                    all        160        160      0.281      0.537      0.244       0.08
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      11/149     0.797G    0.05542    0.01336          0         22        256: 100% 40/40 [00:04<00:00,  8.09it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.32it/s]
#                    all        160        160      0.222      0.331      0.171     0.0509
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      12/149     0.797G    0.05535    0.01436          0         30        256: 100% 40/40 [00:03<00:00, 11.33it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.71it/s]
#                    all        160        160      0.286      0.475      0.277      0.091
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      13/149     0.797G    0.05328    0.01351          0         20        256: 100% 40/40 [00:04<00:00,  9.96it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  3.99it/s]
#                    all        160        160      0.382      0.537      0.312      0.107
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      14/149     0.797G    0.05406     0.0131          0         20        256: 100% 40/40 [00:03<00:00, 10.00it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.84it/s]
#                    all        160        160        0.3      0.488      0.246     0.0813
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      15/149     0.797G    0.05292    0.01367          0         25        256: 100% 40/40 [00:03<00:00, 10.81it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.52it/s]
#                    all        160        160      0.356      0.456      0.332      0.108
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      16/149     0.797G    0.05187    0.01389          0         23        256: 100% 40/40 [00:05<00:00,  7.45it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.42it/s]
#                    all        160        160      0.363      0.381      0.262     0.0804
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      17/149     0.797G    0.05195    0.01389          0         26        256: 100% 40/40 [00:03<00:00, 10.67it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.67it/s]
#                    all        160        160      0.431      0.596      0.423      0.146
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      18/149     0.797G    0.05278    0.01364          0         20        256: 100% 40/40 [00:03<00:00, 10.90it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.23it/s]
#                    all        160        160      0.242      0.438      0.183     0.0575
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      19/149     0.797G    0.05075    0.01362          0         23        256: 100% 40/40 [00:04<00:00,  8.44it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.68it/s]
#                    all        160        160      0.394      0.496      0.345      0.127
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      20/149     0.797G    0.05053    0.01328          0         18        256: 100% 40/40 [00:03<00:00, 11.41it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.80it/s]
#                    all        160        160      0.427      0.525      0.339      0.116
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      21/149     0.797G    0.05207    0.01363          0         28        256: 100% 40/40 [00:04<00:00,  8.95it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.09it/s]
#                    all        160        160       0.42      0.588      0.386      0.145
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      22/149     0.797G    0.05098    0.01347          0         28        256: 100% 40/40 [00:03<00:00, 10.60it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.76it/s]
#                    all        160        160      0.382      0.506      0.382      0.125
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      23/149     0.797G    0.05024    0.01336          0         27        256: 100% 40/40 [00:03<00:00, 10.74it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.91it/s]
#                    all        160        160      0.432      0.431      0.318      0.106
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      24/149     0.797G    0.05102    0.01277          0         18        256: 100% 40/40 [00:05<00:00,  7.55it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.14it/s]
#                    all        160        160      0.417      0.613      0.439      0.162
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      25/149     0.797G    0.05012    0.01343          0         28        256: 100% 40/40 [00:03<00:00, 11.61it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.82it/s]
#                    all        160        160      0.378      0.481      0.317      0.121
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      26/149     0.797G    0.04994    0.01345          0         29        256: 100% 40/40 [00:03<00:00, 10.86it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.27it/s]
#                    all        160        160      0.431      0.562      0.367      0.136
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      27/149     0.797G    0.04929    0.01361          0         23        256: 100% 40/40 [00:04<00:00,  8.48it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.82it/s]
#                    all        160        160      0.429      0.625      0.389      0.141
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      28/149     0.797G    0.04973    0.01328          0         31        256: 100% 40/40 [00:03<00:00, 11.40it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.83it/s]
#                    all        160        160      0.452      0.648      0.411       0.15
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      29/149     0.797G    0.05074    0.01322          0         25        256: 100% 40/40 [00:04<00:00,  8.87it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.08it/s]
#                    all        160        160      0.391      0.477      0.334      0.114
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      30/149     0.797G    0.04772    0.01411          0         28        256: 100% 40/40 [00:03<00:00, 10.68it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.68it/s]
#                    all        160        160      0.407      0.544      0.376      0.138
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      31/149     0.797G    0.04826    0.01294          0         17        256: 100% 40/40 [00:03<00:00, 11.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.71it/s]
#                    all        160        160      0.466      0.606      0.415      0.144
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      32/149     0.797G    0.04924    0.01392          0         24        256: 100% 40/40 [00:05<00:00,  7.32it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.01it/s]
#                    all        160        160      0.432      0.562      0.381      0.143
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      33/149     0.797G    0.04713    0.01354          0         33        256: 100% 40/40 [00:03<00:00, 10.85it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.56it/s]
#                    all        160        160      0.458      0.569      0.409      0.162
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      34/149     0.797G    0.04702    0.01312          0         21        256: 100% 40/40 [00:03<00:00, 11.15it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.24it/s]
#                    all        160        160      0.436       0.59      0.424      0.156
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      35/149     0.797G    0.04777    0.01329          0         29        256: 100% 40/40 [00:04<00:00,  8.37it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.84it/s]
#                    all        160        160      0.443      0.507      0.423      0.141
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      36/149     0.797G    0.04544    0.01314          0         21        256: 100% 40/40 [00:03<00:00, 11.53it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.80it/s]
#                    all        160        160      0.454      0.575      0.428       0.15
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      37/149     0.797G    0.04592    0.01275          0         24        256: 100% 40/40 [00:04<00:00,  9.57it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.02it/s]
#                    all        160        160      0.401       0.55      0.387      0.126
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      38/149     0.797G    0.04766     0.0133          0         28        256: 100% 40/40 [00:04<00:00,  9.96it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.92it/s]
#                    all        160        160      0.429      0.613      0.431      0.155
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      39/149     0.797G    0.04584    0.01319          0         22        256: 100% 40/40 [00:03<00:00, 11.51it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.94it/s]
#                    all        160        160       0.45      0.537      0.399      0.157
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      40/149     0.797G     0.0473    0.01278          0         26        256: 100% 40/40 [00:04<00:00,  8.34it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  3.17it/s]
#                    all        160        160       0.44       0.56      0.376      0.124
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      41/149     0.797G    0.04732    0.01278          0         22        256: 100% 40/40 [00:03<00:00, 11.39it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.67it/s]
#                    all        160        160      0.429      0.525        0.4       0.16
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      42/149     0.797G    0.04607    0.01313          0         27        256: 100% 40/40 [00:03<00:00, 11.64it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.76it/s]
#                    all        160        160      0.459      0.569      0.431      0.163
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      43/149     0.797G    0.04597    0.01343          0         32        256: 100% 40/40 [00:05<00:00,  7.14it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.08it/s]
#                    all        160        160      0.441      0.569      0.437      0.173
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      44/149     0.797G     0.0457    0.01291          0         21        256: 100% 40/40 [00:03<00:00, 11.06it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.51it/s]
#                    all        160        160      0.417      0.556      0.394       0.16
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      45/149     0.797G    0.04468      0.013          0         19        256: 100% 40/40 [00:04<00:00,  9.55it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.15it/s]
#                    all        160        160      0.395      0.537      0.323      0.122
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      46/149     0.797G    0.04508    0.01324          0         27        256: 100% 40/40 [00:04<00:00,  9.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.85it/s]
#                    all        160        160      0.434      0.569      0.428      0.163
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      47/149     0.797G    0.04536    0.01254          0         29        256: 100% 40/40 [00:03<00:00, 11.31it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.76it/s]
#                    all        160        160      0.455      0.631      0.439      0.166
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      48/149     0.797G    0.04358    0.01303          0         23        256: 100% 40/40 [00:04<00:00,  8.38it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.03it/s]
#                    all        160        160      0.423      0.494      0.368      0.144
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      49/149     0.797G    0.04434    0.01297          0         26        256: 100% 40/40 [00:03<00:00, 11.47it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.66it/s]
#                    all        160        160      0.401      0.525      0.405      0.172
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      50/149     0.797G    0.04514    0.01249          0         25        256: 100% 40/40 [00:03<00:00, 11.34it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.76it/s]
#                    all        160        160      0.371      0.594      0.361      0.145
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      51/149     0.797G    0.04379     0.0125          0         26        256: 100% 40/40 [00:05<00:00,  7.55it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.95it/s]
#                    all        160        160      0.413        0.6      0.368      0.131
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      52/149     0.797G    0.04464    0.01267          0         29        256: 100% 40/40 [00:03<00:00, 11.22it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.81it/s]
#                    all        160        160      0.471      0.637      0.474      0.169
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      53/149     0.797G    0.04371     0.0128          0         28        256: 100% 40/40 [00:03<00:00, 11.18it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.96it/s]
#                    all        160        160      0.415      0.519      0.386       0.14
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      54/149     0.797G    0.04241     0.0125          0         28        256: 100% 40/40 [00:05<00:00,  7.97it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.61it/s]
#                    all        160        160      0.406      0.603      0.401      0.164
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      55/149     0.797G    0.04318    0.01227          0         19        256: 100% 40/40 [00:03<00:00, 11.24it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.58it/s]
#                    all        160        160      0.449      0.494      0.389      0.154
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      56/149     0.797G    0.04335    0.01256          0         29        256: 100% 40/40 [00:04<00:00,  9.63it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.09it/s]
#                    all        160        160      0.474      0.706      0.484      0.163
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      57/149     0.797G     0.0422     0.0125          0         15        256: 100% 40/40 [00:04<00:00,  9.70it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.73it/s]
#                    all        160        160      0.487       0.66      0.503      0.196
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      58/149     0.797G    0.04275    0.01223          0         31        256: 100% 40/40 [00:03<00:00, 11.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.87it/s]
#                    all        160        160      0.414      0.581      0.428       0.17
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      59/149     0.797G    0.04191    0.01259          0         27        256: 100% 40/40 [00:05<00:00,  7.65it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.31it/s]
#                    all        160        160      0.495      0.569      0.498      0.176
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      60/149     0.797G    0.04215    0.01293          0         33        256: 100% 40/40 [00:03<00:00, 11.25it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.58it/s]
#                    all        160        160      0.397      0.569      0.386       0.14
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      61/149     0.797G    0.04122    0.01277          0         26        256: 100% 40/40 [00:03<00:00, 11.17it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.78it/s]
#                    all        160        160      0.447       0.57       0.41      0.158
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      62/149     0.797G    0.04162    0.01303          0         25        256: 100% 40/40 [00:05<00:00,  7.49it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.70it/s]
#                    all        160        160      0.479      0.719      0.481       0.17
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      63/149     0.797G    0.04165    0.01258          0         29        256: 100% 40/40 [00:03<00:00, 11.27it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.72it/s]
#                    all        160        160      0.436      0.643      0.461      0.188
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      64/149     0.797G    0.04223    0.01171          0         28        256: 100% 40/40 [00:03<00:00, 10.98it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.31it/s]
#                    all        160        160       0.42        0.5      0.417      0.162
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      65/149     0.797G    0.04183    0.01274          0         23        256: 100% 40/40 [00:04<00:00,  8.70it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.73it/s]
#                    all        160        160      0.438      0.512      0.399      0.147
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      66/149     0.797G    0.04091    0.01239          0         27        256: 100% 40/40 [00:03<00:00, 11.21it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.89it/s]
#                    all        160        160      0.477      0.562      0.451      0.166
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      67/149     0.797G    0.04187    0.01239          0         24        256: 100% 40/40 [00:04<00:00,  8.64it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.04it/s]
#                    all        160        160      0.491      0.475      0.393       0.15
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      68/149     0.797G    0.04089    0.01217          0         27        256: 100% 40/40 [00:03<00:00, 11.07it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.93it/s]
#                    all        160        160      0.421      0.614       0.44      0.154
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      69/149     0.797G    0.04083     0.0128          0         21        256: 100% 40/40 [00:03<00:00, 11.23it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.77it/s]
#                    all        160        160      0.448      0.619      0.467      0.167
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      70/149     0.797G    0.04046    0.01246          0         25        256: 100% 40/40 [00:05<00:00,  7.52it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.04it/s]
#                    all        160        160      0.491       0.65        0.5      0.177
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      71/149     0.797G    0.04165    0.01264          0         24        256: 100% 40/40 [00:03<00:00, 11.31it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.68it/s]
#                    all        160        160      0.494      0.675      0.488      0.174
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      72/149     0.797G    0.03978    0.01193          0         20        256: 100% 40/40 [00:03<00:00, 11.43it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.05it/s]
#                    all        160        160      0.516      0.619      0.497      0.173
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      73/149     0.797G    0.03976    0.01261          0         25        256: 100% 40/40 [00:05<00:00,  7.88it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.81it/s]
#                    all        160        160      0.476      0.654      0.472      0.182
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      74/149     0.797G    0.04099    0.01186          0         26        256: 100% 40/40 [00:03<00:00, 11.41it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.66it/s]
#                    all        160        160      0.456      0.613       0.43       0.16
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      75/149     0.797G    0.03956    0.01195          0         18        256: 100% 40/40 [00:04<00:00,  9.71it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.13it/s]
#                    all        160        160      0.484      0.637      0.452      0.167
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      76/149     0.797G    0.03945    0.01232          0         22        256: 100% 40/40 [00:04<00:00,  9.59it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.73it/s]
#                    all        160        160      0.404      0.575      0.377      0.148
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      77/149     0.797G     0.0394    0.01257          0         24        256: 100% 40/40 [00:03<00:00, 11.27it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.74it/s]
#                    all        160        160       0.46      0.613      0.438      0.178
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      78/149     0.797G    0.03823    0.01138          0         23        256: 100% 40/40 [00:05<00:00,  7.93it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.17it/s]
#                    all        160        160      0.476       0.68      0.503      0.192
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      79/149     0.797G     0.0392    0.01264          0         28        256: 100% 40/40 [00:03<00:00, 11.12it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.85it/s]
#                    all        160        160      0.534      0.552      0.491      0.188
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      80/149     0.797G    0.03888     0.0124          0         32        256: 100% 40/40 [00:03<00:00, 11.52it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.73it/s]
#                    all        160        160      0.496      0.644       0.51      0.205
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      81/149     0.797G    0.03862    0.01245          0         25        256: 100% 40/40 [00:05<00:00,  7.75it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.83it/s]
#                    all        160        160      0.474      0.625      0.473      0.173
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      82/149     0.797G    0.03873    0.01209          0         27        256: 100% 40/40 [00:03<00:00, 10.66it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.92it/s]
#                    all        160        160      0.476      0.715      0.493      0.187
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      83/149     0.797G    0.03886    0.01214          0         26        256: 100% 40/40 [00:04<00:00, 10.00it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.16it/s]
#                    all        160        160      0.479      0.579      0.443      0.174
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      84/149     0.797G    0.03843    0.01259          0         22        256: 100% 40/40 [00:04<00:00,  9.35it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.81it/s]
#                    all        160        160      0.491      0.633       0.48      0.189
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      85/149     0.797G    0.03759    0.01186          0         26        256: 100% 40/40 [00:03<00:00, 11.21it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.91it/s]
#                    all        160        160      0.479      0.656      0.493      0.191
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      86/149     0.797G    0.03739    0.01192          0         26        256: 100% 40/40 [00:04<00:00,  8.50it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  3.99it/s]
#                    all        160        160      0.453      0.616      0.451      0.192
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      87/149     0.797G    0.03708    0.01199          0         31        256: 100% 40/40 [00:03<00:00, 11.09it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.64it/s]
#                    all        160        160      0.484      0.613      0.469      0.183
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      88/149     0.797G    0.03677     0.0117          0         24        256: 100% 40/40 [00:03<00:00, 11.04it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.78it/s]
#                    all        160        160      0.474      0.613      0.469       0.19
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      89/149     0.797G    0.03744    0.01221          0         31        256: 100% 40/40 [00:05<00:00,  7.26it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.49it/s]
#                    all        160        160      0.463      0.619      0.465       0.18
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      90/149     0.797G    0.03694    0.01198          0         26        256: 100% 40/40 [00:03<00:00, 11.05it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.74it/s]
#                    all        160        160      0.505      0.637      0.501      0.201
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      91/149     0.797G    0.03736    0.01253          0         24        256: 100% 40/40 [00:03<00:00, 11.19it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.45it/s]
#                    all        160        160      0.489      0.599      0.485      0.185
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      92/149     0.797G    0.03699    0.01215          0         36        256: 100% 40/40 [00:04<00:00,  8.24it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.59it/s]
#                    all        160        160      0.469      0.619      0.475      0.191
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      93/149     0.797G    0.03723    0.01157          0         26        256: 100% 40/40 [00:03<00:00, 11.24it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.90it/s]
#                    all        160        160      0.489      0.681      0.479      0.198
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      94/149     0.797G    0.03659    0.01186          0         22        256: 100% 40/40 [00:04<00:00,  9.44it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.04it/s]
#                    all        160        160      0.508      0.725      0.547      0.203
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      95/149     0.797G    0.03722    0.01222          0         23        256: 100% 40/40 [00:03<00:00, 10.18it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.89it/s]
#                    all        160        160      0.505      0.675      0.529      0.194
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      96/149     0.797G    0.03584    0.01166          0         24        256: 100% 40/40 [00:03<00:00, 11.09it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.01it/s]
#                    all        160        160       0.45      0.656       0.44       0.17
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      97/149     0.797G    0.03597    0.01174          0         21        256: 100% 40/40 [00:05<00:00,  7.53it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.63it/s]
#                    all        160        160      0.447      0.706      0.458      0.162
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      98/149     0.797G    0.03566    0.01154          0         22        256: 100% 40/40 [00:03<00:00, 11.18it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.66it/s]
#                    all        160        160      0.468      0.688      0.449      0.165
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#      99/149     0.797G    0.03513    0.01157          0         22        256: 100% 40/40 [00:03<00:00, 11.18it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.01it/s]
#                    all        160        160      0.497      0.668        0.5      0.186
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     100/149     0.797G    0.03604    0.01168          0         24        256: 100% 40/40 [00:05<00:00,  7.85it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.75it/s]
#                    all        160        160      0.488      0.644       0.46      0.167
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     101/149     0.797G    0.03556    0.01133          0         28        256: 100% 40/40 [00:03<00:00, 11.25it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.91it/s]
#                    all        160        160      0.495      0.612      0.438      0.168
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     102/149     0.797G    0.03546    0.01161          0         25        256: 100% 40/40 [00:04<00:00,  9.95it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.03it/s]
#                    all        160        160      0.504      0.631      0.495      0.192
#
# ...
#     112/149     0.797G    0.03416    0.01123          0         27        256: 100% 40/40 [00:03<00:00, 11.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.82it/s]
#                    all        160        160      0.554       0.55      0.486      0.183
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     113/149     0.797G    0.03345     0.0111          0         24        256: 100% 40/40 [00:03<00:00, 10.34it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  3.86it/s]
#                    all        160        160      0.491      0.579      0.457      0.177
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     114/149     0.797G    0.03258    0.01072          0         26        256: 100% 40/40 [00:04<00:00,  9.19it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.78it/s]
#                    all        160        160      0.483      0.644      0.468      0.186
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     115/149     0.797G    0.03308    0.01105          0         26        256: 100% 40/40 [00:03<00:00, 11.34it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.86it/s]
#                    all        160        160      0.525      0.588      0.514      0.183
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     116/149     0.797G    0.03254    0.01096          0         30        256: 100% 40/40 [00:04<00:00,  8.86it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.11it/s]
#                    all        160        160       0.48      0.588      0.461      0.187
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     117/149     0.797G    0.03297     0.0112          0         25        256: 100% 40/40 [00:03<00:00, 10.99it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.93it/s]
#                    all        160        160      0.529      0.569      0.498      0.186
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     118/149     0.797G    0.03343    0.01129          0         29        256: 100% 40/40 [00:03<00:00, 11.24it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  6.02it/s]
#                    all        160        160      0.521      0.605      0.509      0.189
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     119/149     0.797G    0.03324    0.01052          0         21        256: 100% 40/40 [00:05<00:00,  7.59it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.83it/s]
#                    all        160        160      0.527      0.606      0.468      0.183
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     120/149     0.797G     0.0327    0.01157          0         25        256: 100% 40/40 [00:03<00:00, 11.24it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.85it/s]
#                    all        160        160      0.501      0.659      0.465      0.178
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     121/149     0.797G    0.03235     0.0111          0         27        256: 100% 40/40 [00:03<00:00, 10.70it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.90it/s]
#                    all        160        160      0.503      0.644       0.48      0.186
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     122/149     0.797G    0.03311    0.01126          0         20        256: 100% 40/40 [00:05<00:00,  7.98it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.96it/s]
#                    all        160        160      0.465      0.694      0.486      0.184
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     123/149     0.797G      0.032    0.01082          0         22        256: 100% 40/40 [00:03<00:00, 11.45it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.95it/s]
#                    all        160        160      0.456      0.688      0.471      0.186
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     124/149     0.797G     0.0316    0.01105          0         24        256: 100% 40/40 [00:03<00:00, 10.18it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.09it/s]
#                    all        160        160      0.487      0.693      0.507      0.189
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     125/149     0.797G    0.03147    0.01101          0         22        256: 100% 40/40 [00:04<00:00,  9.35it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.69it/s]
#                    all        160        160      0.504        0.7      0.507      0.187
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     126/149     0.797G    0.03167    0.01074          0         26        256: 100% 40/40 [00:03<00:00, 11.08it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  6.04it/s]
#                    all        160        160      0.529      0.688      0.507      0.191
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     127/149     0.797G     0.0312     0.0105          0         21        256: 100% 40/40 [00:04<00:00,  8.80it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.03it/s]
#                    all        160        160        0.5      0.626      0.491      0.189
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     128/149     0.797G    0.03104    0.01062          0         26        256: 100% 40/40 [00:03<00:00, 11.27it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.92it/s]
#                    all        160        160       0.49      0.606       0.46      0.177
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     129/149     0.797G    0.03084    0.01033          0         27        256: 100% 40/40 [00:03<00:00, 11.47it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.87it/s]
#                    all        160        160      0.516      0.606      0.475      0.175
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     130/149     0.797G    0.03054    0.01042          0         24        256: 100% 40/40 [00:05<00:00,  7.73it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.62it/s]
#                    all        160        160      0.496      0.613      0.467      0.173
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     131/149     0.797G      0.031    0.01075          0         30        256: 100% 40/40 [00:03<00:00, 11.34it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.84it/s]
#                    all        160        160      0.488      0.644      0.456      0.178
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     132/149     0.797G    0.03163    0.01099          0         24        256: 100% 40/40 [00:03<00:00, 11.31it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.78it/s]
#                    all        160        160      0.445      0.675      0.444      0.178
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     133/149     0.797G     0.0313    0.01031          0         24        256: 100% 40/40 [00:05<00:00,  7.95it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.94it/s]
#                    all        160        160      0.468      0.632      0.444      0.173
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     134/149     0.797G    0.02877    0.01027          0         24        256: 100% 40/40 [00:03<00:00, 11.22it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.82it/s]
#                    all        160        160      0.514      0.631      0.467      0.179
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     135/149     0.797G     0.0303    0.01056          0         21        256: 100% 40/40 [00:03<00:00, 10.82it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.14it/s]
#                    all        160        160      0.512      0.619      0.471      0.184
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     136/149     0.797G    0.03014    0.01014          0         26        256: 100% 40/40 [00:04<00:00,  9.12it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.89it/s]
#                    all        160        160      0.517      0.637      0.475      0.185
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     137/149     0.797G    0.03085    0.01116          0         20        256: 100% 40/40 [00:03<00:00, 11.28it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.93it/s]
#                    all        160        160      0.499      0.694      0.487      0.183
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     138/149     0.797G    0.03048    0.01018          0         20        256: 100% 40/40 [00:04<00:00,  9.22it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.27it/s]
#                    all        160        160      0.494      0.669      0.479      0.178
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     139/149     0.797G    0.02982    0.01048          0         28        256: 100% 40/40 [00:03<00:00, 10.18it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  6.00it/s]
#                    all        160        160      0.493      0.669      0.478      0.177
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     140/149     0.797G    0.02995    0.01011          0         22        256: 100% 40/40 [00:03<00:00, 11.34it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.98it/s]
#                    all        160        160      0.514      0.656      0.472      0.176
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     141/149     0.797G    0.02947   0.009963          0         18        256: 100% 40/40 [00:04<00:00,  8.10it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.17it/s]
#                    all        160        160        0.5      0.662       0.47      0.183
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     142/149     0.797G    0.02944    0.01042          0         25        256: 100% 40/40 [00:03<00:00, 11.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  6.04it/s]
#                    all        160        160      0.514      0.706      0.493      0.183
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     143/149     0.797G    0.02884    0.01024          0         17        256: 100% 40/40 [00:03<00:00, 11.25it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.93it/s]
#                    all        160        160      0.498      0.706      0.498      0.191
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     144/149     0.797G    0.02882    0.01034          0         25        256: 100% 40/40 [00:05<00:00,  7.19it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.80it/s]
#                    all        160        160      0.537      0.619      0.497      0.187
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     145/149     0.797G    0.02877   0.009948          0         23        256: 100% 40/40 [00:03<00:00, 11.22it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.81it/s]
#                    all        160        160      0.487      0.651      0.468      0.182
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     146/149     0.797G    0.02864   0.009802          0         17        256: 100% 40/40 [00:03<00:00, 11.36it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  4.17it/s]
#                    all        160        160      0.498      0.675      0.472      0.187
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     147/149     0.797G    0.02884    0.01059          0         24        256: 100% 40/40 [00:04<00:00,  8.61it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  6.01it/s]
#                    all        160        160      0.522      0.675      0.486      0.188
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     148/149     0.797G    0.02869   0.009809          0         18        256: 100% 40/40 [00:03<00:00, 11.55it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:00<00:00,  5.85it/s]
#                    all        160        160      0.539      0.662      0.487      0.186
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#     149/149     0.797G    0.02806    0.01022          0         18        256: 100% 40/40 [00:04<00:00,  9.85it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:01<00:00,  3.76it/s]
#                    all        160        160      0.534      0.656      0.488      0.185
#
# 150 epochs completed in 0.233 hours.
# Optimizer stripped from runs/train/exp/weights/last.pt, 14.3MB
# Optimizer stripped from runs/train/exp/weights/best.pt, 14.3MB
#
# Validating runs/train/exp/weights/best.pt...
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 5/5 [00:02<00:00,  1.97it/s]
#                    all        160        160      0.506      0.725      0.546      0.203
# Results saved to runs/train/exp

# %%
# !python detect.py --weights runs/train/exp/weights/best.pt --img 256 --conf 0.2 --source /content/drive/MyDrive/tbx11k-simplified/test
# Out:
# detect: weights=['runs/train/exp/weights/best.pt'], source=/content/drive/MyDrive/tbx11k-simplified/test, data=data/coco128.yaml, imgsz=[256, 256], conf_thres=0.2, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# requirements: /content/drive/MyDrive/tbx11k-simplified/requirements.txt not found, check failed.
# YOLOv5 🚀 v7.0-162-gc3e4e94 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/4 /content/drive/MyDrive/tbx11k-simplified/test/tb1192.png: 256x256 2 TBs, 6.2ms
# image 2/4 /content/drive/MyDrive/tbx11k-simplified/test/tb1194.png: 256x256 1 TB, 6.6ms
# image 3/4 /content/drive/MyDrive/tbx11k-simplified/test/tb1196.png: 256x256 2 TBs, 6.1ms
# image 4/4 /content/drive/MyDrive/tbx11k-simplified/test/tb1197.png: 256x256 2 TBs, 6.4ms
# Speed: 0.4ms pre-process, 6.3ms inference, 32.0ms NMS per image at shape (1, 3, 256, 256)
# Results saved to runs/detect/exp
